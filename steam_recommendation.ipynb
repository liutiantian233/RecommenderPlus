# %%
import json
from urllib.request import urlopen
import requests,json,os,sys,time,re
import pandas as pd
import numpy as np

# %%
def show_work_status(singleCount, totalCount, currentCount):
    currentCount+=singleCount
    percentage=1.*currentCount/totalCount*100
    status='>'*int(percentage/2)+'-'*(50-int(percentage/2))
    if percentage % 3:
        sys.stdout.write('\rStatus:[{0}]{1:.2f}%'.format(status,percentage))
        sys.stdout.flush()
    if percentage>=100: print('\n')

# %%
content_data = pd.read_csv('new_steam_games.csv')
content_data
# Out:
#        Positive  Negative                     Game_name  Positive_Rate  \
# 0         39146      3404                          DOOM           0.92
# 1        409937    426671  PLAYERUNKNOWNS BATTLEGROUNDS           0.49
# 2          4991      2039                    BATTLETECH           0.71
# 3        101940     65175                          DayZ           0.61
# 4          8495      2986                    EVE Online           0.74
# ...         ...       ...                           ...            ...
# 17358        17         0                       Grabity           1.00
# 17359        10         4        Detached NonVR Edition           0.78
# 17360         9         2                 A Room Beyond           0.90
# 17361         7         3             Chasing the Stars           0.70
# 17362         3        11                        Nanoui           0.28
#
#                                                     Link
# 0        https://store.steampowered.com/app/379720/DOOM/
# 1      https://store.steampowered.com/app/578080/PLAY...
# 2      https://store.steampowered.com/app/637090/BATT...
# 3        https://store.steampowered.com/app/221100/DayZ/
# 4      https://store.steampowered.com/app/8500/EVE_On...
# ...                                                  ...
# 17358  https://store.steampowered.com/app/652810/Grab...
# 17359  https://store.steampowered.com/app/848410/Deta...
# 17360  https://store.steampowered.com/app/454330/A_Ro...
# 17361  https://store.steampowered.com/app/763990/Chas...
# 17362  https://store.steampowered.com/app/809080/Nanoui/
#
# [17363 rows x 5 columns]

# %%
import urllib
import bs4
from bs4 import BeautifulSoup
Game_description = pd.Series([]) 
current_count = 0
for i in range(100):
    url = content_data['Link'][i]
    url_contents = urllib.request.urlopen(url).read()
    soup = bs4.BeautifulSoup(url_contents, 'html.parser')
    div = soup.find("div", {"id": "game_area_description"})
    ########## Fina the area of game descriptiona ##########
    Game_description[i]=div
    show_work_status(1,100,current_count)
    current_count+=1
# Out:
# Status:[>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%

# %%
soup = bs4.BeautifulSoup(url_contents, 'html.parser')
div = soup.find("div", {"id": "game_area_description"})

content = str(div)
content_data['Game_description'] = Game_description
content_data['Game_description'] = content_data['Game_description'].apply(str)
content_data
# Out:
#        Positive  Negative                     Game_name  Positive_Rate  \
# 0         39146      3404                          DOOM           0.92
# 1        409937    426671  PLAYERUNKNOWNS BATTLEGROUNDS           0.49
# 2          4991      2039                    BATTLETECH           0.71
# 3        101940     65175                          DayZ           0.61
# 4          8495      2986                    EVE Online           0.74
# ...         ...       ...                           ...            ...
# 17358        17         0                       Grabity           1.00
# 17359        10         4        Detached NonVR Edition           0.78
# 17360         9         2                 A Room Beyond           0.90
# 17361         7         3             Chasing the Stars           0.70
# 17362         3        11                        Nanoui           0.28
#
#                                                     Link  \
# 0        https://store.steampowered.com/app/379720/DOOM/
# 1      https://store.steampowered.com/app/578080/PLAY...
# 2      https://store.steampowered.com/app/637090/BATT...
# 3        https://store.steampowered.com/app/221100/DayZ/
# 4      https://store.steampowered.com/app/8500/EVE_On...
# ...                                                  ...
# 17358  https://store.steampowered.com/app/652810/Grab...
# 17359  https://store.steampowered.com/app/848410/Deta...
# 17360  https://store.steampowered.com/app/454330/A_Ro...
# 17361  https://store.steampowered.com/app/763990/Chas...
# 17362  https://store.steampowered.com/app/809080/Nanoui/
#
#                                         Game_description
# 0      <div class="game_area_description" id="game_ar...
# 1      <div class="game_area_description" id="game_ar...
# 2      <div class="game_area_description" id="game_ar...
# 3      <div class="game_area_description" id="game_ar...
# 4      <div class="game_area_description" id="game_ar...
# ...                                                  ...
# 17358                                                nan
# 17359                                                nan
# 17360                                                nan
# 17361                                                nan
# 17362                                                nan
#
# [17363 rows x 6 columns]

# %%
print(content_data['Game_description'][1])
# Out:
# <div class="game_area_description" id="game_area_description">
# <h2>About This Game</h2>
# <strong>LAND, LOOT, SURVIVE!</strong><br/>Play PUBG: BATTLEGROUNDS for free.<br/>Land on strategic locations, loot weapons and supplies, and survive to become the last team standing across various, diverse Battlegrounds.<br/>Squad up and join the Battlegrounds for the original Battle Royale experience that only PUBG: BATTLEGROUNDS can offer.<br/><br/>This content download will also provide access to the BATTLEGROUNDS Test Server, which requires a separate download to play. <br/>Optional in-game purchases available.						</div>

# %%
import string
current_count = 0
for i in range(0,100):
    content_data['Game_description'][i] = re.sub('<.*?>', ' ', content_data['Game_description'][i])
    content_data['Game_description'][i] = re.sub('\\n.*\\n', ' ', content_data['Game_description'][i])
    content_data['Game_description'][i] = content_data['Game_description'][i].replace("\t","")
    content_data['Game_description'][i] = content_data['Game_description'][i].translate(content_data['Game_description'][i].maketrans(' ',' ',string.punctuation))

    show_work_status(1,100,current_count)
    current_count+=1
# Out:
# Status:[>>>>>>>>>>>>>>>>>---------------------------------]35.00%
# Status:[>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%

# %%
content_data.head(5)
# Out:
#    Positive  Negative                     Game_name  Positive_Rate  \
# 0     39146      3404                          DOOM           0.92
# 1    409937    426671  PLAYERUNKNOWNS BATTLEGROUNDS           0.49
# 2      4991      2039                    BATTLETECH           0.71
# 3    101940     65175                          DayZ           0.61
# 4      8495      2986                    EVE Online           0.74
#
#                                                 Link  \
# 0    https://store.steampowered.com/app/379720/DOOM/
# 1  https://store.steampowered.com/app/578080/PLAY...
# 2  https://store.steampowered.com/app/637090/BATT...
# 3    https://store.steampowered.com/app/221100/DayZ/
# 4  https://store.steampowered.com/app/8500/EVE_On...
#
#                                     Game_description
# 0    Developed by id software the studio that pio...
# 1     LAND LOOT SURVIVE  Play PUBG BATTLEGROUNDS ...
# 2       From original BATTLETECHMechWarrior creat...
# 3    DayZ is a hardcore openworld survival game w...
# 4     THE 1 SPACE MMO   EVE Online is the largest...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel,cosine_similarity
tfidf_vectorizer = TfidfVectorizer(strip_accents = 'unicode',stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(list(content_data['Game_description']))
#Need to convert every Series in DataFrame to List format
tfidf_vectorizer.get_feature_names()
#Array mapping from feature integer indices to feature name
#print(tfidf)  ####Tf-idf-weighted document-term matrix.     (0, 3473)	0.4059439800797409   (0, 1417)	0.08671197437269683
# Out:
# ['0100',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '1000yearold',
#  '1080p',
#  '10th',
#  '11',
#  '110',
#  '1100',
#  '1142',
#  '12',
#  '13',
#  '130',
#  '13th',
#  '14',
#  '14th',
#  '15',
#  '16',
#  '160',
#  '17',
#  '170',
#  '1796',
#  '18',
#  '180',
#  '1802',
#  '1803',
#  '1807',
#  '18ft',
#  '19',
#  '1912',
#  '1984',
#  '1988',
#  '1999',
#  '1realistic',
#  '1v1',
#  '20',
#  '200',
#  '20000',
#  '2015',
#  '2020',
#  '2021',
#  '2022',
#  '20mm',
#  '20th',
#  '21',
#  '22',
#  '23',
#  '230',
#  '2300',
#  '2478',
#  '25',
#  '250',
#  '26',
#  '27',
#  '28',
#  '2d',
#  '2e',
#  '2nd',
#  '2various',
#  '2x',
#  '30',
#  '300',
#  '3025',
#  '34',
#  '35',
#  '350',
#  '35e',
#  '36',
#  '38',
#  '3d',
#  '3dmark',
#  '3rd',
#  '3unique',
#  '3vs3',
#  '40',
#  '400',
#  '40000',
#  '45',
#  '48',
#  '4e',
#  '4k',
#  '4multiple',
#  '50',
#  '500',
#  '5000',
#  '501st',
#  '51',
#  '510',
#  '5e',
#  '60',
#  '600',
#  '6000',
#  '60fps',
#  '60man',
#  '64',
#  '64bit',
#  '65',
#  '650000',
#  '67',
#  '6player',
#  '6v6',
#  '70',
#  '700',
#  '7000',
#  '7x',
#  '80',
#  '800',
#  '80s',
#  '840',
#  '86',
#  '865',
#  '867',
#  '870',
#  '872',
#  '873',
#  '877',
#  '878',
#  '8825',
#  '8player',
#  '8th',
#  '8v8',
#  '8way',
#  '90',
#  '927',
#  'aa',
#  'abandoned',
#  'abilities',
#  'ability',
#  'able',
#  'aboard',
#  'absorb',
#  'absorbing',
#  'absurd',
#  'abundance',
#  'abundant',
#  'abyssal',
#  'academy',
#  'accepting',
#  'access',
#  'accessed',
#  'accessibility',
#  'accessories',
#  'accident',
#  'acclaimed',
#  'accompanied',
#  'accomplish',
#  'according',
#  'accordingly',
#  'accumulated',
#  'accuracy',
#  'accurately',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieving',
#  'achilles',
#  'acquire',
#  'acquired',
#  'acted',
#  'acting',
#  'action',
#  'actionpacked',
#  'actions',
#  'activate',
#  'activated',
#  'activates',
#  'activating',
#  'active',
#  'activities',
#  'activity',
#  'actual',
#  'actually',
#  'ad',
#  'adapt',
#  'adapted',
#  'adapts',
#  'add',
#  'added',
#  'addictive',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'addon',
#  'addons',
#  'adds',
#  'adeptus',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjustments',
#  'adoptive',
#  'adorable',
#  'adrenaline',
#  'adrenalinepumping',
#  'advance',
#  'advanced',
#  'advancement',
#  'advantage',
#  'adventure',
#  'adventurer',
#  'adventurers',
#  'adventures',
#  'adventuring',
#  'adventurous',
#  'aed',
#  'aeldari',
#  'aelle',
#  'aerial',
#  'aero',
#  'aerodynamics',
#  'aerospace',
#  'aesthetics',
#  'afar',
#  'affect',
#  'affects',
#  'afforded',
#  'afire',
#  'afloat',
#  'africa',
#  'aftermath',
#  'agamemnon',
#  'age',
#  'ageless',
#  'agent',
#  'agents',
#  'aggressively',
#  'agile',
#  'agility',
#  'aging',
#  'agony',
#  'agreements',
#  'ahead',
#  'ai',
#  'aid',
#  'aided',
#  'aiko',
#  'aims',
#  'air',
#  'airborne',
#  'aircity',
#  'aircraft',
#  'airship',
#  'airships',
#  'airstrikes',
#  'aka',
#  'akira',
#  'alba',
#  'album',
#  'alchemy',
#  'alert',
#  'alfred',
#  'alien',
#  'aliens',
#  'aligned',
#  'alignment',
#  'alike',
#  'alive',
#  'allconsuming',
#  'allegiance',
#  'alliance',
#  'alliances',
#  'allies',
#  'allnew',
#  'allornothing',
#  'allotted',
#  'allout',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'allpowerful',
#  'allterrain',
#  'alltime',
#  'alongside',
#  'alpha',
#  'alt',
#  'alter',
#  'altering',
#  'alternation',
#  'amalur',
#  'amazing',
#  'ambiguity',
#  'ambiguous',
#  'ambitious',
#  'ambitiously',
#  'ambushed',
#  'amd',
#  'america',
#  'american',
#  'americas',
#  'ammo',
#  'amn',
#  'amoebas',
#  'amp',
#  'analysisbot',
#  'anaraut',
#  'ancient',
#  'andor',
#  'android',
#  'andrzej',
#  'angle',
#  'anglers',
#  'anglia',
#  'angling',
#  'anglo',
#  'anglosaxon',
#  'anglosaxons',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'animations',
#  'anime',
#  'annihilate',
#  'anniversary',
#  'announcements',
#  'annoying',
#  'answers',
#  'ante',
#  'anticheat',
#  'anticipated',
#  'antics',
#  'antitank',
#  'anxiety',
#  'anytime',
#  'apaches',
#  'apart',
#  'apcs',
#  'aperture',
#  'apm',
#  'apocalypse',
#  'apologies',
#  'appear',
#  'appearance',
#  'appetite',
#  'application',
#  'applied',
#  'apply',
#  'approach',
#  'approaching',
#  'april',
#  'aragami',
#  'arc',
#  'arcade',
#  'arcades',
#  'arcadia',
#  'arcane',
#  'architects',
#  'area',
#  'areas',
#  'arena',
#  'arenastyle',
#  'argument',
#  'arguments',
#  'arid',
#  'arkane',
#  'arm',
#  'armada',
#  'armed',
#  'armies',
#  'armor',
#  'armorclad',
#  'armored',
#  'armors',
#  'armory',
#  'armoured',
#  'armoury',
#  'arms',
#  'army',
#  'arpg',
#  'array',
#  'arrived',
#  'arrives',
#  'arrow',
#  'arrows',
#  'arsenal',
#  'art',
#  'artbook',
#  'artefacts',
#  'artgal',
#  'artifacts',
#  'artificial',
#  'artilleries',
#  'artillery',
#  'artist',
#  'artists',
#  'arts',
#  'ascend',
#  'ascent',
#  'ash',
#  'asia',
#  'aspect',
#  'aspects',
#  'aspired',
#  'aspires',
#  'assailant',
#  'assassin',
#  'assassination',
#  'assault',
#  'assaults',
#  'assemble',
#  'assembled',
#  'assessment',
#  'asset',
#  'assets',
#  'assign',
#  'assimilate',
#  'assist',
#  'assistance',
#  'assistant',
#  'associated',
#  'association',
#  'assume',
#  'astronaut',
#  'athe',
#  'athletics',
#  'atlantic',
#  'atmosphere',
#  'atmospheric',
#  'atrocities',
#  'atrt',
#  'attachable',
#  'attack',
#  'attacked',
#  'attacking',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attending',
#  'attention',
#  'attitudes',
#  'attracted',
#  'attraction',
#  'attractive',
#  'attributes',
#  'au',
#  'auction',
#  'audience',
#  'audio',
#  'augment',
#  'augmented',
#  'aumaua',
#  'auriga',
#  'aurora',
#  'authentic',
#  'author',
#  'authored',
#  'auto',
#  'autocannons',
#  'automatic',
#  'automatically',
#  'automation',
#  'automatons',
#  'autosave',
#  'autosaving',
#  'autumn',
#  'availability',
#  'available',
#  'avatar',
#  'average',
#  'avid',
#  'avoid',
#  'await',
#  'awaits',
#  'awakens',
#  'award',
#  'awards',
#  'awardwinning',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'axe',
#  'axes',
#  'axis',
#  'aztec',
#  'aztecs',
#  'babylon',
#  'backdrop',
#  'background',
#  'backgrounds',
#  'backpack',
#  'backstreets',
#  'backwards',
#  'badass',
#  'badge',
#  'badges',
#  'bakuya',
#  'balance',
#  'balanced',
#  'balancing',
#  'baldur',
#  'baldurs',
#  'ball',
#  'ballad',
#  'ballistic',
#  'balloon',
#  'band',
#  'bands',
#  'bank',
#  'banks',
#  'baptised',
#  'bar',
#  'barbarian',
#  'barbed',
#  'barc',
#  'bardic',
#  'bardr',
#  'bare',
#  'barrel',
#  'base',
#  'based',
#  'bases',
#  'bashir',
#  'basic',
#  'basically',
#  'basics',
#  'basketball',
#  'bass',
#  'bastion',
#  'bathroom',
#  'battle',
#  'battlecruisers',
#  'battlefield',
#  'battlefields',
#  'battlefleet',
#  'battlefront',
#  'battlefronts',
#  'battlegrounds',
#  'battlemechs',
#  'battleroyalelike',
#  'battles',
#  'battleships',
#  'battletechmechwarrior',
#  'battling',
#  'bay',
#  'beacons',
#  'beam',
#  'beans',
#  'bear',
#  'bearing',
#  'beast',
#  'beasts',
#  'beat',
#  'beautiful',
#  'beauty',
#  'beef',
#  'befriend',
#  'beg',
#  'began',
#  'begin',
#  'beginning',
#  'begins',
#  'behave',
#  'behavior',
#  'behemoth',
#  'beholder',
#  'beliefs',
#  'believably',
#  'belisarius',
#  'bellic',
#  'bellicose',
#  'beloved',
#  'benchmarks',
#  'bend',
#  'beneath',
#  'bent',
#  'bespoke',
#  'best',
#  'bested',
#  'bestiary',
#  'bestow',
#  'bestselling',
#  'bet',
#  'betrayal',
#  'betrayed',
#  'better',
#  'bgm',
#  'bhaal',
#  'bicycles',
#  'bid',
#  'bidiot',
#  'bidiots',
#  'big',
#  'bigger',
#  'biggest',
#  'biker',
#  'bikes',
#  'bilbo',
#  'billie',
#  'billion',
#  'billions',
#  'bimonthly',
#  'biomes',
#  'bios',
#  'bioshock',
#  'biosignal',
#  'birthright',
#  'bison',
#  'bit',
#  'biting',
#  'bitingstriking',
#  'bizarre',
#  'black',
#  'blackguard',
#  'blade',
#  'blank',
#  'blast',
#  'blastia',
#  'blend',
#  'blends',
#  'blind',
#  'blindness',
#  'blitzball',
#  'bloc',
#  'block',
#  'blockade',
#  'blockbuster',
#  'blocks',
#  'blood',
#  'bloodlust',
#  'bloodshed',
#  'bloodsoaked',
#  'bloodthirsty',
#  'bloody',
#  'blow',
#  'blowing',
#  'blows',
#  'blue',
#  'blueprint',
#  'blueprints',
#  'bluffing',
#  'blunted',
#  'blurs',
#  'bmx',
#  'board',
#  'boards',
#  'boats',
#  'boba',
#  'bodies',
#  'body',
#  'boldest',
#  'bomb',
#  'bombdefusing',
#  'bombers',
#  'bombs',
#  'bond',
#  'bonds',
#  'bonecrunching',
#  'boneless',
#  'boneloaf',
#  'bonus',
#  'bonuses',
#  'boo',
#  'book',
#  'booker',
#  'books',
#  'boost',
#  'boosters',
#  'boosts',
#  'boots',
#  'bootsonthe',
#  'border',
#  'borders',
#  'born',
#  'borrow',
#  'boss',
#  'bosses',
#  'bot',
#  'bots',
#  'boulder',
#  'boutique',
#  'bow',
#  'bowonly',
#  'bows',
#  'box',
#  'boys',
#  'bpo',
#  'br',
#  'branching',
#  'brand',
#  'brandnew',
#  'brave',
#  'braveheart',
#  'brawl',
#  'brawler',
#  'break',
#  'breaker',
#  'breaking',
#  'breakout',
#  'breaks',
#  'breath',
#  'breathing',
#  'breathtaking',
#  'bree',
#  'brian',
#  'bribery',
#  'brief',
#  'brigand',
#  'bright',
#  'bring',
#  'bringing',
#  'brings',
#  'britain',
#  'britannia',
#  'britannic',
#  'british',
#  'britons',
#  'brittonic',
#  'broadcasts',
#  'broaden',
#  'broforce',
#  'broken',
#  'brother',
#  'brotherhood',
#  'brothers',
#  'brought',
#  'browse',
#  'brunt',
#  'brutal',
#  'brutally',
#  'bubbles',
#  'buddha',
#  'budding',
#  'buffs',
#  'bug',
#  'build',
#  'builder',
#  'builders',
#  'building',
#  'buildings',
#  'builds',
#  'built',
#  'builtin',
#  'bulk',
#  'bull',
#  'bunch',
#  'bundle',
#  'burden',
#  'burgeoning',
#  'burger',
#  'burst',
#  'burstfiring',
#  'bursts',
#  'business',
#  'businessmen',
#  'busy',
#  'butcher',
#  'button',
#  'buttons',
#  'buy',
#  'buying',
#  'cabaret',
#  'cabin',
#  'cabling',
#  'cafeteria',
#  'cage',
#  'calendar',
#  'calibrate',
#  'california',
#  'called',
#  'calling',
#  'calls',
#  'calm',
#  'camaraderie',
#  'came',
#  'camera',
#  'camouflage',
#  'campaign',
#  'campaigns',
#  'camps',
#  'cannon',
#  'cannons',
#  'canvas',
#  'canyon',
#  'capabilities',
#  'capable',
#  'capacity',
#  'capcom',
#  'cape',
#  'capital',
#  'capitalism',
#  'capitulation',
#  'capsuleer',
#  'capsuleers',
#  'capt',
#  'captain',
#  'captivating',
#  'captive',
#  'capturable',
#  'capture',
#  'captured',
#  'car',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'careful',
#  'carefully',
#  'cargo',
#  'carnage',
#  'carpenter',
#  'carries',
#  'carry',
#  'cars',
#  'carter',
#  'cartridges',
#  'carve',
#  'case',
#  'cases',
#  'cast',
#  'castellanos',
#  'castle',
#  'castles',
#  'casual',
#  'casualties',
#  'catapult',
#  'catastrophic',
#  'catch',
#  'catches',
#  'category',
#  'caught',
#  'cause',
#  'caused',
#  'cavalry',
#  'caverns',
#  'caves',
#  'cawl',
#  'ceaseless',
#  'ceiling',
#  'celebrate',
#  'cell',
#  'celshaded',
#  'celtic',
#  'cemetery',
#  'center',
#  'central',
#  'centred',
#  'century',
#  'ceowulf',
#  'cerberus',
#  'certain',
#  'chains',
#  'challenge',
#  'challenges',
#  'challenging',
#  'chamber',
#  'champion',
#  'chance',
#  'change',
#  'changes',
#  'changing',
#  'chanter',
#  'chaos',
#  'chapter',
#  'chapters',
#  'character',
#  'characteristics',
#  'characters',
#  'charge',
#  'charged',
#  'charismatic',
#  'charming',
#  'charts',
#  'chase',
#  'chastened',
#  'chat',
#  'cheating',
#  'check',
#  'checkpoints',
#  'cheerful',
#  'chef',
#  'chieftains',
#  'child',
#  'childhood',
#  'children',
#  'chilling',
#  'chinese',
#  'chip',
#  'chisel',
#  'choice',
#  'choices',
#  'choose',
#  'choosing',
#  'choreography',
#  'chosen',
#  'christianity',
#  'chronology',
#  'cinaeda',
#  'cinematic',
#  'cinematics',
#  'cipher',
#  'circenn',
#  'circumstances',
#  'cis',
#  'cities',
#  'citizen',
#  'citizens',
#  'city',
#  'civil',
#  'civilization',
#  'civilizations',
#  'civilized',
#  'claim',
#  'claiming',
#  'clan',
#  'clans',
#  'clash',
#  'class',
#  'classes',
#  'classic',
#  'classical',
#  'classics',
#  'classified',
#  'classmates',
#  'classsystem',
#  'claws',
#  'clean',
#  'cleaned',
#  'cleaner',
#  'cleanup',
#  'clear',
#  'clears',
#  'cleave',
#  'click',
#  'client',
#  'clients',
#  'climate',
#  'climatic',
#  'climb',
#  'clinging',
#  'clink',
#  'cloak',
#  'clockwork',
#  'clone',
#  'clones',
#  'close',
#  'closecombat',
#  'closed',
#  'closequarters',
#  'cloud',
#  'clouds',
#  'cloudy',
#  'club',
#  'clubs',
#  'clues',
#  'clut',
#  'clyde',
#  'coalesced',
#  'coast',
#  'coaster',
#  'coasters',
#  'coax',
#  'coconuts',
#  'cocreator',
#  'coin',
#  'coins',
#  'cold',
#  'collaboration',
#  'collect',
#  'collectable',
#  'collected',
#  'collectibles',
#  'collecting',
#  'collection',
#  'collectively',
#  'collide',
#  'collision',
#  'collisions',
#  'colonies',
#  'colonists',
#  'colonization',
#  'colony',
#  'color',
#  'colors',
#  'colossal',
#  'colossus',
#  'colour',
#  'colourful',
#  'colours',
#  'columbia',
#  'coma',
#  'combat',
#  'combatants',
#  'combination',
#  'combinations',
#  'combine',
#  'combined',
#  'combines',
#  'combining',
#  'combo',
#  'combos',
#  'come',
#  'comeback',
#  ...]

# %%
list_app_name = list(content_data['Game_name'])
content_data['Game_description']
# Out:
# 0          Developed by id software the studio that pio...
# 1           LAND LOOT SURVIVE  Play PUBG BATTLEGROUNDS ...
# 2             From original BATTLETECHMechWarrior creat...
# 3          DayZ is a hardcore openworld survival game w...
# 4           THE 1 SPACE MMO   EVE Online is the largest...
#                                ...
# 17358                                                  nan
# 17359                                                  nan
# 17360                                                  nan
# 17361                                                  nan
# 17362                                                  nan
# Name: Game_description, Length: 17363, dtype: object

# %%
dic_recommended_1 = {}
for index in range(content_data['Game_description'].shape[0]):
    #Iterate items in DataFrame
    similarities_1 = linear_kernel(tfidf[index],tfidf).flatten()
    ####For each game，tfidf value list is a very long list，tfidf[index:index+1] calculates all of the words'tfidf for one game,
    related_docs_indices_1 = (-similarities_1).argsort()[1:11]
    #related_docs_indices_2 = similarities_2.argsort()[:-10:-1]
    #argsort returns an array of indices of the same shape as 
    dic_recommended_1.update({list_app_name[index]:[list_app_name[i] for i in related_docs_indices_1]})
df_content_based_results_1 = pd.DataFrame(dic_recommended_1)
#df_content_based_results_1.index.name = 'steam_appname'
df_content_based_results_1.reset_index(inplace=True)

# %%
df_content_based_results_1 = df_content_based_results_1.T
print(df_content_based_results_1.shape)
df_content_based_results_1
# Out:
# (17290, 10)
#                                                         0                  1  \
# index                                                   0                  1
# DOOM                                              Golf It  Call of Duty WWII
# PLAYERUNKNOWNS BATTLEGROUNDS                 Realm Royale          Northgard
# BATTLETECH                                Battle Brothers   Heroes  Generals
# DayZ                                    They Are Billions          Frostpunk
# ...                                                   ...                ...
# Grabity                       Battle Fleet Ground Assault        Bass Blocks
# Detached NonVR Edition        Battle Fleet Ground Assault        Bass Blocks
# A Room Beyond                 Battle Fleet Ground Assault        Bass Blocks
# Chasing the Stars             Battle Fleet Ground Assault        Bass Blocks
# Nanoui                        Battle Fleet Ground Assault        Bass Blocks
#
#                                                                       2  \
# index                                                                 2
# DOOM                                           Dungeons  Dragons Online
# PLAYERUNKNOWNS BATTLEGROUNDS                               Desert Skies
# BATTLETECH                    Total War MEDIEVAL II  Definitive Edition
# DayZ                                                    The Evil Within
# ...                                                                 ...
# Grabity                                                        The Deer
# Detached NonVR Edition                                         The Deer
# A Room Beyond                                                  The Deer
# Chasing the Stars                                              The Deer
# Nanoui                                                         The Deer
#
#                                                            3  \
# index                                                      3
# DOOM                          Clone Drone in the Danger Zone
# PLAYERUNKNOWNS BATTLEGROUNDS        Dungeons  Dragons Online
# BATTLETECH                                 Call of Duty WWII
# DayZ                                The Jackbox Party Pack 2
# ...                                                      ...
# Grabity                                  Kanji Training Game
# Detached NonVR Edition                   Kanji Training Game
# A Room Beyond                            Kanji Training Game
# Chasing the Stars                        Kanji Training Game
# Nanoui                                   Kanji Training Game
#
#                                                                  4  \
# index                                                            4
# DOOM                                        Call of Duty Black Ops
# PLAYERUNKNOWNS BATTLEGROUNDS             The Elder Scrolls Legends
# BATTLETECH                                              War Robots
# DayZ                                                   Stonehearth
# ...                                                            ...
# Grabity                       Star Conflict Fleet Strength  Mauler
# Detached NonVR Edition        Star Conflict Fleet Strength  Mauler
# A Room Beyond                 Star Conflict Fleet Strength  Mauler
# Chasing the Stars             Star Conflict Fleet Strength  Mauler
# Nanoui                        Star Conflict Fleet Strength  Mauler
#
#                                                                 5  \
# index                                                           5
# DOOM                                   Men of War Assault Squad 2
# PLAYERUNKNOWNS BATTLEGROUNDS                           EVE Online
# BATTLETECH                             Men of War Assault Squad 2
# DayZ                          Neverwinter Nights Enhanced Edition
# ...                                                           ...
# Grabity                        Just Cause 3 DLC Mech Land Assault
# Detached NonVR Edition         Just Cause 3 DLC Mech Land Assault
# A Room Beyond                  Just Cause 3 DLC Mech Land Assault
# Chasing the Stars              Just Cause 3 DLC Mech Land Assault
# Nanoui                         Just Cause 3 DLC Mech Land Assault
#
#                                                                        6  \
# index                                                                  6
# DOOM                          The Witcher Enhanced Edition Directors Cut
# PLAYERUNKNOWNS BATTLEGROUNDS            Keep Talking and Nobody Explodes
# BATTLETECH                            STAR WARS Empire at War  Gold Pack
# DayZ                                        GOD WARS The Complete Legend
# ...                                                                  ...
# Grabity                              Star Conflict Fleet Strength  Razor
# Detached NonVR Edition               Star Conflict Fleet Strength  Razor
# A Room Beyond                        Star Conflict Fleet Strength  Razor
# Chasing the Stars                    Star Conflict Fleet Strength  Razor
# Nanoui                               Star Conflict Fleet Strength  Razor
#
#                                                      7  \
# index                                                7
# DOOM                                             Forts
# PLAYERUNKNOWNS BATTLEGROUNDS         Call of Duty WWII
# BATTLETECH                           Between the Stars
# DayZ                          Dungeons  Dragons Online
# ...                                                ...
# Grabity                            What Are You Stupid
# Detached NonVR Edition             What Are You Stupid
# A Room Beyond                      What Are You Stupid
# Chasing the Stars                  What Are You Stupid
# Nanoui                             What Are You Stupid
#
#                                                            8  \
# index                                                      8
# DOOM                                         Devil May Cry 5
# PLAYERUNKNOWNS BATTLEGROUNDS                       The Surge
# BATTLETECH                            Call of Duty Black Ops
# DayZ                          Clone Drone in the Danger Zone
# ...                                                      ...
# Grabity                              Distant Worlds Universe
# Detached NonVR Edition               Distant Worlds Universe
# A Room Beyond                        Distant Worlds Universe
# Chasing the Stars                    Distant Worlds Universe
# Nanoui                               Distant Worlds Universe
#
#                                                    9
# index                                              9
# DOOM                                 ShellShock Live
# PLAYERUNKNOWNS BATTLEGROUNDS            For The King
# BATTLETECH                              For The King
# DayZ                          Call of Duty Black Ops
# ...                                              ...
# Grabity                           The Dark Inside Me
# Detached NonVR Edition            The Dark Inside Me
# A Room Beyond                     The Dark Inside Me
# Chasing the Stars                 The Dark Inside Me
# Nanoui                            The Dark Inside Me
#
# [17290 rows x 10 columns]

# %%
print(content_data['Game_name'].tolist())
# Out:
# ['DOOM', 'PLAYERUNKNOWNS BATTLEGROUNDS', 'BATTLETECH', 'DayZ', 'EVE Online', 'Devil May Cry 5', 'Human Fall Flat', 'They Are Billions', 'Warhammer Chaosbane', 'For The King', 'Danganronpa V3 Killing Harmony', 'TERA', 'Call of Duty Modern Warfare Remastered', 'Stonehearth', 'Clone Drone in the Danger Zone', 'GOD EATER 3', 'War Robots', 'Halo Wars Definitive Edition', 'Call of Duty Black Ops', 'Phoenix Wright Ace Attorney Trilogy  123', 'Team Sonic Racing', 'Titan Quest Anniversary Edition', 'Grand Theft Auto IV', 'Portal', 'Viscera Cleanup Detail', 'Neverwinter Nights Enhanced Edition', 'Ni no Kuni II Revenant Kingdom', 'Tree of Savior English Ver', 'Hellblade Senuas Sacrifice', 'Danganronpa 2 Goodbye Despair', 'Yakuza 0', 'The Escapists 2', 'Star Wars Battlefront 2 Classic 2005', 'Wizard101', 'Life is Strange 2', 'Kingdoms of Amalur Reckoning', 'GOD WARS The Complete Legend', 'CounterStrike Source', 'The Evil Within', 'Bright MemoryEarly Access', 'STAR WARS Empire at War  Gold Pack', 'Dishonored Death of the Outsider', 'Street Fighter V', 'The Jackbox Party Pack 2', 'Armored Battle Crew World War 1  Tank Warfare and Crew Management Simulator', 'Battlefleet Gothic Armada 2', 'RUNNING WITH RIFLES', 'The Witcher Enhanced Edition Directors Cut', 'Middleearth Shadow of War', 'Forts', 'The Lord of the Rings Online', 'Dungeon Munchies', 'Pillars of Eternity', 'Graveyard Keeper', 'The Elder Scrolls Legends', 'Northgard', 'Realm Royale', 'Gang Beasts', 'Total War MEDIEVAL II  Definitive Edition', 'Tales of Vesperia Definitive Edition', 'FINAL FANTASY XX2 HD Remaster', 'Return of the Obra Dinn', 'Castle Crashers', 'Call of Duty WWII', 'MudRunner', 'Keep Talking and Nobody Explodes', 'SPORE', 'Contra Anniversary Collection', 'Fishing Planet', 'Just Cause 3', 'BioShock Infinite', 'Men of War Assault Squad 2', 'Dungeons  Dragons Online', 'JUMP FORCE', 'Desert Skies', 'Ring of Elysium', 'METAL GEAR SOLID V THE PHANTOM PAIN', 'TEKKEN 7', 'Golf It', 'Shadow Tactics Blades of the Shogun', 'Heroes  Generals', 'Ultimate Doom', 'GORN', 'DRAGON BALL FighterZ', 'Fantasy Grounds', 'DRAGON BALL XENOVERSE 2', 'Frostpunk', 'Universe Sandbox', 'Shadowverse CCG', 'Fable Anniversary', 'Baldurs Gate II Enhanced Edition', 'Freestyle 2 Street Basketball', 'PC Building Simulator', 'Battle Brothers', 'The Surge', 'Total War Saga THRONES OF BRITANNIA', 'Parkitect', 'Between the Stars', 'ShellShock Live', 'Endless Legend', 'Devolver Bootleg', 'DiRT Rally 20', 'Attack on Titan 2  AOT2', 'Warface', 'Assassins Creed Origins', 'House Party', 'Empyrion  Galactic Survival', 'WWE 2K19', 'Dragons Dogma Dark Arisen', 'Warhammer 40000 Gladius  Relics of War', 'Scrap Mechanic', 'Generation Zero', 'Total War ATTILA', 'Prison Architect', 'Eco', 'Thief Simulator', 'Bloons TD 6', 'DUSK', 'Ori and the Blind Forest', 'Wizard of Legend', 'MapleStory 2', 'The Jackbox Party Pack 4', 'EARTH DEFENSE FORCE 41 The Shadow of New Despair', 'Steam Controller', 'Two Point Hospital', 'The Universim', 'Sniper Elite 4', 'Divinity Original Sin  Enhanced Edition', 'Automation  The Car Company Tycoon Game', 'SCUM', 'Reventure', 'Job Simulator', 'Watch Dogs 2', 'Town of Salem', 'VEGA Conflict', 'Foundation', 'Shadow of the Tomb Raider', 'Golf With Your Friends', 'The Witcher 2 Assassins of Kings Enhanced Edition', 'The Elder Scrolls IV Oblivion Game of the Year Edition', 'Company of Heroes 2', 'PlanetSide 2', 'Rocksmith 2014 Edition  Remastered', 'Naval Action', 'ACE COMBAT 7 SKIES UNKNOWN', 'Vacation Simulator', 'Baldurs Gate Enhanced Edition', 'The Golf Club 2019 featuring PGA TOUR', 'Far Cry 5', 'Pummel Party', 'Idle Champions of the Forgotten Realms', 'The Isle', 'iRacing', 'Hot Dogs Horseshoes  Hand Grenades', 'Crush Crush', 'Call of Duty Black Ops II', 'Undertale', 'The Evil Within 2', 'Project CARS 2', 'FINAL FANTASY VII', 'Euro Truck Simulator 2', 'Endless Space 2', 'Stick Fight The Game', 'Fell Seal Arbiters Mark', 'Out of the Park Baseball 20', 'Project Winter', 'Dishonored', 'Assetto C ...

# %% [markdown]
# Example Output

# %%
# can edit this to verify if an input game name exist in the dataset
name = 'RESIDENT EVIL 7 biohazard  BIOHAZARD 7 resident evil'
id = content_data.index[content_data['Game_name'] == name][0]
id
# Out:
# 659

# %%
user_profile = [["DARK SOULS III", 286], ['Grand Theft Auto V', 45], ['Portal 2', 8], ['RESIDENT EVIL 7 biohazard  BIOHAZARD 7 resident evil', 88], ['Sekiro Shadows Die Twice', 1.4]]

# %%
names = []
for i in range(len(user_profile)):
  names.append(user_profile[i][0])
  if user_profile[i][1] <= 2:
    user_profile[i][1] = 0.1
  elif user_profile[i][1] > 2 and user_profile[i][1] <= 10:
    user_profile[i][1] = 0.5
  elif user_profile[i][1] > 10 and user_profile[i][1] <= 50:
    user_profile[i][1] = 0.8
  elif user_profile[i][1] > 50 and user_profile[i][1] <= 100: 
    user_profile[i][1] = 1
  else:
    user_profile[i][1] = 1.2
user_profile
# Out:
# [['DARK SOULS III', 1.2],
#  ['Grand Theft Auto V', 0.8],
#  ['Portal 2', 0.5],
#  ['RESIDENT EVIL 7 biohazard  BIOHAZARD 7 resident evil', 1],
#  ['Sekiro Shadows Die Twice', 0.1]]

# %%
recommendations = {}
for game in user_profile:
  name = game[0]
  id = content_data.index[content_data['Game_name'] == name][0]
  similarities = linear_kernel(tfidf[id],tfidf).flatten()
  related_docs_indices = (-similarities).argsort()[1:11]
  lam = 0
  for i in related_docs_indices:
    new_game = list_app_name[i]
    if new_game not in names:
      if new_game not in recommendations:
        recommendations.update({new_game: game[1]-lam})
      else:
        value = recommendations.get(new_game)
        recommendations.update({new_game: value+game[1]-lam})
    lam += 0.01

recommendations = dict(sorted(recommendations.items(), key=lambda item: item[1], reverse=True))
print(recommendations)
# Out:
# {'Battle Fleet Ground Assault': 3.6, 'Bass Blocks': 3.5500000000000007, 'The Deer': 3.5, 'Kanji Training Game': 3.4500000000000006, 'Star Conflict Fleet Strength  Mauler': 3.4, 'Just Cause 3 DLC Mech Land Assault': 3.3500000000000005, 'Star Conflict Fleet Strength  Razor': 3.3, 'What Are You Stupid': 3.2500000000000004, 'Distant Worlds Universe': 3.1999999999999997, 'The Dark Inside Me': 3.1500000000000004}

# %%
output = []
count = 0
for key in recommendations:
  output.append(key)
  count += 1
  if count >= 10:
    break
output
# Out:
# ['Battle Fleet Ground Assault',
#  'Bass Blocks',
#  'The Deer',
#  'Kanji Training Game',
#  'Star Conflict Fleet Strength  Mauler',
#  'Just Cause 3 DLC Mech Land Assault',
#  'Star Conflict Fleet Strength  Razor',
#  'What Are You Stupid',
#  'Distant Worlds Universe',
#  'The Dark Inside Me']
